# %%
import googlemaps
import pprint
import time
#from GoogleMapsAPIKey import get_my_key
#Define our API Key

API_KEY = 'MyGoogleAPIKey'

#Define our client
gmaps = googlemaps.Client(key = API_KEY)

searchfor = 'hamburgueria' #search by name or tag
lat_long = '-23.962410, -46.328109' #latitude and longitude
r = 5000 # radius in meter


#Define our Search

# searching by tag
#places_result = gmaps.places_nearby(location = lat_long, radius = r, open_now = False, type = searchfor)

#searching by name
places_result = gmaps.places_nearby(location = lat_long, radius = r, open_now = False, name = searchfor)


pprint.pprint(places_result)
# Out:
# {'html_attributions': [],
#  'next_page_token': 'CrQCIwEAAKqDaPsuUBY2Cm-b8laB2F6ovXs0U04zZ_nJwb-_VBvqtILI6Qc0ydYFVtoqgrW_JcEnoA9T0XS79Z4SJFq9bxzm4e0uHXM94tbZiJz1c67jsexw3DOIJqZ_pRHZ0zi_83evdeKdPBr9X5vHPtBAGabMa1PQi9HMWfp_7_KS9CTk5qvORkIQfF_8Nuby27_rAKpLY2LFjFxir1Oa2seUwFzYXvSMdByKzJ9XDbPQTTsoVFBvQoykQDnUoROrfR4HLNwbC2qb4FMbEvHsm1HX7uqbZGg5RLjsnyE3imM2VuBOQMsqeSEhiuukmcx627y63ZhWxfCI4q-ke2gTs_fOwYna-jVQHGtshBS-jAhA_iCrIqBky16a-2aRMgINAH5zFZaXibJKtKyX7zRT15lK_YUSEH1bd4ribw3ZiqfI2XZTMnUaFNBY-tNV1fpm4wJwwx3pl6B5JUTp',
#  'results': [{'geometry': {'location': {'lat': -23.9660648, 'lng': -46.3300752},
#                            'viewport': {'northeast': {'lat': -23.96479557010727,
#                                                       'lng': -46.32873052010728},
#                                         'southwest': {'lat': -23.96749522989272,
#                                                       'lng': -46.33143017989272}}},
# ...
